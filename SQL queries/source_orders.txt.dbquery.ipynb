-- %%
-- CREATE TABLE ORDERS (
--     order_id INT,
--     order_date date,
--     customer_id INT,
--     order_status string
-- );

-- insert into orders 
-- values 
-- (1, '2020-01-01', 1, 'PENDING'),
-- (2, '2020-01-02', 2, 'DELIVERED'),
-- (3, '2020-01-03', 3, 'COMPLETE'),
-- (4, '2020-01-04', 4, 'PENDING'),
-- (5, '2020-01-05', 5, 'CANCELLED');

----add more rows

insert into orders values (
  6, '2020-01-06', 6, 'PENDING'
),
(7, '2020-01-06', 7, 'COMPLETE')
